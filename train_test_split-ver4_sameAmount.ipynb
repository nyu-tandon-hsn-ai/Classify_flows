# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
df = pd.read_csv("./concatenate_v4_sameAmount.csv")
df = df.drop(df.columns[0], axis=1)

df = df.dropna(axis=0, how='any')
print(len(df))
# Out:
# 1998

# %%
df.head(5)
# Out:
#    avg(pkt_len)  stddev(pkt_len)  fb_ratio  inter_arrival_time  pkt_count  \
# 0   1351.216495        21.825928 -1.000000            0.002169        776
# 1   1352.000000         0.000000 -1.000000            0.000096        775
# 2   1308.384519       120.063304 -1.000000            0.002301        801
# 3   1423.619469        97.135910 -1.000000            0.055105        565
# 4    195.933333       371.472834  0.271744            0.162144         15
#
#     duration  is_tcp  tot_pkt_len  fwd_pkt_len  bwd_pkt_len    outcome
# 0   1.680606       1    1048544.0    1048544.0          0.0  streaming
# 1   0.074181       1    1047800.0    1047800.0          0.0   download
# 2   1.841134       1    1048016.0    1048016.0          0.0  streaming
# 3  31.079112       1     804345.0     804345.0          0.0       game
# 4   2.270020       1       2939.0        628.0       2311.0       voip

# %%
for item in df.outcome.unique():
    print (item, (df.outcome == item).sum())
# Out:
# streaming 498
# download 500
# game 500
# voip 500

# %%
## change to 0.50 0.25 0.75

## train : test = .8 : .2
train_normal, test_normal = train_test_split(df, test_size=0.5)

# ## train : test = 0.75 : 0.25
# train_normal, test_normal = train_test_split(df_normal, test_size=0.75)

# ## train : test = 0.25 : 0.75
# train_normal, test_normal = train_test_split(df_normal, test_size=0.25)

# %%
print(len(train_normal),len(test_normal))
# Out:
# 999 999

# %%
train_normal.head(20)
# Out:
#       avg(pkt_len)  stddev(pkt_len)  fb_ratio  inter_arrival_time  pkt_count  \
# 57       73.200000        20.571825  1.859375            0.017486          5
# 1004     70.923810        11.512280 -1.000000            0.002947        105
# 1663    193.840000       364.809960  0.429077            0.007500         25
# 653     347.000000       488.311807  0.454012            0.266814         20
# 872     195.933333       371.472834  0.271744            0.093039         15
# 814     257.000000       309.712770  0.079832            0.002480          2
# 413      73.200000        20.571825  1.859375            0.026075          5
# 1977   1352.000000         0.000000 -1.000000            0.000106        775
# 895     301.845091        78.935415 -1.000000            0.061984       3473
# 763     280.000000       335.168614  0.083172            0.003055          2
# 1676     86.500000        37.476659  0.530973            0.093855          2
# 337     187.846154       356.766444  0.423907            0.005180         26
# 1859     64.000000         0.000000  2.000000            0.002060          3
# 1378    140.500000         0.707107 -1.000000            0.000085          2
# 993     182.000000         0.000000 -1.000000            1.000811          4
# 1068   1352.000000         0.000000 -1.000000            0.000591        775
# 1715   1352.000000         0.000000 -1.000000            0.000257        775
# 1589   1303.050995       129.033503 -1.000000            0.001681        804
# 1197     41.000000         0.000000 -1.000000            0.410803          2
# 730    1305.636364       124.528627 -1.000000            0.002472        803
#
#         duration  is_tcp  tot_pkt_len  fwd_pkt_len  bwd_pkt_len    outcome
# 57      0.069943       1        366.0        238.0        128.0   download
# 1004    0.306517       1       7447.0       7447.0          0.0       game
# 1663    0.179999       1       4846.0       1455.0       3391.0   download
# 653     5.069462       1       6940.0       2167.0       4773.0       voip
# 872     1.302540       1       2939.0        628.0       2311.0       voip
# 814     0.002480       0        514.0         38.0        476.0  streaming
# 413     0.104301       1        366.0        238.0        128.0  streaming
# 1977    0.081794       1    1047800.0    1047800.0          0.0   download
# 895   215.207408       0    1048308.0    1048308.0          0.0       game
# 763     0.003055       0        560.0         43.0        517.0  streaming
# 1676    0.093855       0        173.0         60.0        113.0       game
# 337     0.129506       1       4884.0       1454.0       3430.0       game
# 1859    0.004120       1        192.0        128.0         64.0  streaming
# 1378    0.000085       0        281.0        281.0          0.0       voip
# 993     3.002434       0        728.0        728.0          0.0       game
# 1068    0.457225       1    1047800.0    1047800.0          0.0  streaming
# 1715    0.199023       1    1047800.0    1047800.0          0.0  streaming
# 1589    1.349962       1    1047653.0    1047653.0          0.0  streaming
# 1197    0.410803       0         82.0         82.0          0.0       game
# 730     1.982901       1    1048426.0    1048426.0          0.0  streaming

# %%
for item in test_normal.outcome.unique():
    print (item, (test_normal.outcome == item).sum())
# Out:
# streaming 236
# game 267
# voip 248
# download 248

# %%
# train test split on no sampled data

train_normal.to_csv('./train_50%_v4.csv')
test_normal.to_csv('./test_50%_v4.csv')

# %%
# # train test split on upsampled data

# train_normal.to_csv('/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/test/upsampled/upsampled_samp@80%_.csv')
# test_normal.to_csv('/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/test/upsampled/upsampled_samp@80%_.csv')

# %%
# # train test split on upsampled data

# train_normal.to_csv('/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/test/no_upsampled/train_nosampled_50%.csv')
# test_normal.to_csv('/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/test/no_upsampled/test_nosampled_50%.csv')
